# %%
# %pylab inline
from sklearn import svm
import numpy as np
import matplotlib.pyplot as plt
from numpy import genfromtxt
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('vibmon.csv')
df.head()
# Out:
#       SensorName LastCommunicationDate  X_mms  Y_mms  Z_mms  X_hz  Y_hz  Z_hz  \
# 0  Sensor-300578      08-08-2017 08:14   20.0   20.4   16.7    14    12    17
# 1  Sensor-300577      08-08-2017 08:17   25.0   24.3   10.8    15    11    19
# 2  Sensor-300575      08-08-2017 08:18    9.6    2.5    3.2    11    10    13
# 3  Sensor-300579      08-08-2017 08:18   15.1    2.1    1.5    12     9    12
# 4  Sensor-300578      08-08-2017 08:24   13.1   12.2    0.1    10    13    22
#
#    Fault
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
x = np.array([datetime.datetime(2013, 9, 28, i, 0) for i in range(24)])
y = np.random.randint(100, size=x.shape)

plt.plot(x,y)
plt.show()

# %%
# y = df.X_mms.head()
y = df.iloc[0:200].X_mms
# x = df.LastCommunicationDate.head()
x = df.iloc[0:200].LastCommunicationDate
plt.plot(x,y)
plt.show()

# %%
# y = df.X_mms.head()
y = df.iloc[0:300].Y_mms
# x = df.LastCommunicationDate.head()
x = df.iloc[0:300].LastCommunicationDate
plt.plot(x,y)
plt.show()

# %%
# y = df.X_mms.head()
y = df.iloc[0:300].Z_mms
# x = df.LastCommunicationDate.head()
x = df.iloc[0:300].LastCommunicationDate
plt.plot(x,y)
plt.show()

# %%
foo = df.iloc[0:300]
foo.head()
# Out:
#       SensorName LastCommunicationDate  X_mms  Y_mms  Z_mms  X_hz  Y_hz  Z_hz  \
# 0  Sensor-300578      08-08-2017 08:14   20.0   20.4   16.7    14    12    17
# 1  Sensor-300577      08-08-2017 08:17   25.0   24.3   10.8    15    11    19
# 2  Sensor-300575      08-08-2017 08:18    9.6    2.5    3.2    11    10    13
# 3  Sensor-300579      08-08-2017 08:18   15.1    2.1    1.5    12     9    12
# 4  Sensor-300578      08-08-2017 08:24   13.1   12.2    0.1    10    13    22
#
#    Fault
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
# foo.drop(['Fault', 'SensorName', 'Y_mms', 'Y_mms', 'Y_mms', 'Y_mms', 'Y_mms', ], axis=1)
df1 = df[['LastCommunicationDate','X_mms']]
df1.plot()

# %%
# df1 = df[['LastCommunicationDate','Y_mms', 'X_mms', 'Z_mms']]
# df1.plot()
df1 = df[['LastCommunicationDate','X_mms']]
df1.plot(color='b')
df1 = df[['LastCommunicationDate','Z_mms']]
df1.plot()
df1 = df[['LastCommunicationDate','Y_mms']]
df1.plot()

# %%
df1 = df[['LastCommunicationDate','X_mms']]
df1.plot(kind='kde', color='b')

# %%
df1 = df[['LastCommunicationDate','Y_mms']]
df1.plot(kind='kde', color='b')

# %%
from pandas.tools.plotting import autocorrelation_plot
df1 = df[['X_mms']]
autocorrelation_plot(df1.iloc[1:200])
# Out:
# C:\Users\sushil.shah\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: 'pandas.tools.plotting.autocorrelation_plot' is deprecated, import 'pandas.plotting.autocorrelation_plot' instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df1 = df[['Y_mms']]
autocorrelation_plot(df1.iloc[1:200])
# Out:
# C:\Users\sushil.shah\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: 'pandas.tools.plotting.autocorrelation_plot' is deprecated, import 'pandas.plotting.autocorrelation_plot' instead.

# %%
df1 = df[['Z_mms']]
autocorrelation_plot(df1.iloc[1:200])
# Out:
# C:\Users\sushil.shah\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: 'pandas.tools.plotting.autocorrelation_plot' is deprecated, import 'pandas.plotting.autocorrelation_plot' instead.

# %%
df1 = df[['X_hz']]
autocorrelation_plot(df1.iloc[1:200])
# Out:
# C:\Users\sushil.shah\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: 'pandas.tools.plotting.autocorrelation_plot' is deprecated, import 'pandas.plotting.autocorrelation_plot' instead.

# %%
df1 = df[['Y_hz']]
autocorrelation_plot(df1.iloc[1:200])
# Out:
# C:\Users\sushil.shah\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: 'pandas.tools.plotting.autocorrelation_plot' is deprecated, import 'pandas.plotting.autocorrelation_plot' instead.

# %%
df.loc[df['SensorName'] == 'Sensor-300578'].X_mms.plot()

# %%
df2= df.loc[df['SensorName'] == 'Sensor-300578']
# df2
from pandas.tools.plotting import bootstrap_plot
data = df2.X_mms
bootstrap_plot(data, size=50, samples=100, color='grey')
# Out:
# C:\Users\sushil.shah\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: 'pandas.tools.plotting.bootstrap_plot' is deprecated, import 'pandas.plotting.bootstrap_plot' instead.
#   """
